# %%
# Type hints
from typing import Any, Dict, List, Tuple, Optional

# Standard library
import ast
import logging
import re
import warnings
import os

# Third-party packages - Data manipulation
import pandas as pd
from tqdm import tqdm

# Third-party packages - Environment & Database
from dotenv import load_dotenv
from neo4j import GraphDatabase

# Third-party packages - Error handling & Retry logic
from tenacity import retry, stop_after_attempt, wait_exponential

# Langchain - Core
from langchain.chains import GraphCypherQAChain
from langchain.prompts import PromptTemplate
from langchain_core.documents import Document

# Langchain - Models & Connectors
from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAI

# Suppress warnings
warnings.filterwarnings('ignore')

# Load environment variables
load_dotenv()


api_key = os.getenv("AIzaSyB_Ykzslx0N_kKYeUN5jPr-LF7gLqo8ddM")

# %%
movies = pd.read_csv('wiki_movie_plots.csv')

movies.head()
# Out:
#    Release Year                             Title Origin/Ethnicity  \
# 0          1901            Kansas Saloon Smashers         American
# 1          1901     Love by the Light of the Moon         American
# 2          1901           The Martyred Presidents         American
# 3          1901  Terrible Teddy, the Grizzly King         American
# 4          1902            Jack and the Beanstalk         American
#
#                              Director Cast    Genre  \
# 0                             Unknown  NaN  unknown
# 1                             Unknown  NaN  unknown
# 2                             Unknown  NaN  unknown
# 3                             Unknown  NaN  unknown
# 4  George S. Fleming, Edwin S. Porter  NaN  unknown
#
#                                            Wiki Page  \
# 0  https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1  https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2  https://en.wikipedia.org/wiki/The_Martyred_Pre...
# 3  https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# 4  https://en.wikipedia.org/wiki/Jack_and_the_Bea...
#
#                                                 Plot
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# 2  The film, just over a minute long, is composed...
# 3  Lasting just 61 seconds and consisting of two ...
# 4  The earliest known adaptation of the classic f...

# %%
def clean_data(df: pd.DataFrame) -> pd.DataFrame:
    """Clean and preprocess DataFrame.
    
    Args:
        data: Input DataFrame
        
    Returns:
        Cleaned DataFrame
    """
    df.drop(["Wiki Page"], axis=1, inplace=True)
    df.drop(["Release Year"], axis=1, inplace=True)
    df = df.rename(columns={'Origin/Ethnicity': 'Ethnicity'})


    # Drop duplicates
    df = df.drop_duplicates(subset='Title', keep='first')
    
    # Get object columns
    col_obj = df.select_dtypes(include=["object"]).columns
    
    # Clean string columns
    for col in col_obj:
        # Strip whitespace
        df[col] = df[col].str.strip()
        
        # Replace unknown/empty values
        df[col] = df[col].apply(
            lambda x: None if pd.isna(x) or x.lower() in ["", "unknown"] 
            else x.capitalize()
        )
    
    # Drop rows with any null values
    df = df.dropna(how="any", axis=0)
    
    return df

movies = clean_data(movies).head(1000)
movies.head()
# Out:
#                        Title Ethnicity  \
# 13              Daniel boone  American
# 15              Laughing gas  American
# 16  The adventures of dollie  American
# 17           The black viper  American
# 18    A calamitous elopement  American
#
#                                    Director  \
# 13  Wallace mccutcheon and ediwin s. porter
# 15                     Edwin stanton porter
# 16                           D. w. griffith
# 17                           D. w. griffith
# 18                            D.w. griffith
#
#                                  Cast         Genre  \
# 13  William craven, florence lawrence  Biographical
# 15    Bertha regustus, edward boulden        Comedy
# 16  Arthur v. johnson, linda arvidson         Drama
# 17                     D. w. griffith         Drama
# 18       Harry solter, linda arvidson        Comedy
#
#                                                  Plot
# 13  Boone's daughter befriends an indian maiden as...
# 15  The plot is that of a black woman going to the...
# 16  On a beautiful summer day a father and mother ...
# 17  A thug accosts a girl as she leaves her workpl...
# 18  A young couple decides to elope after being ca...

# %%
# Set up Neo4j connection
class Neo4jConnection:
    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        self.driver.close()
        print("Connection closed")

    def reset_database(self):
        with self.driver.session() as session:
            session.run("MATCH (n) DETACH DELETE n")
        print("Database resetted successfully!")

    def add_document(self, documents: list):
        self.driver.add_graph_documents(documents)

    def execute_query(self, query, parameters=None):
        with self.driver.session() as session:
            result = session.run(query, parameters or {})
            return [record for record in result]

# Connect to Neo4j
uri = "neo4j://localhost:7687"
user = "neo4j"
password = "moviesplot"
conn = Neo4jConnection(uri, user, password)

# %%
# just making sure the database is empty
conn.reset_database()
# Out:
# Database resetted successfully!

# %% [markdown]
# Manual Upload

# %%
def parse_number(value: Any, target_type: type) -> Optional[float]:
    """Parse string to number with proper error handling."""
    if pd.isna(value):
        return None
    try:
        cleaned = str(value).strip().replace(',', '')
        return target_type(cleaned)
    except (ValueError, TypeError):
        return None

def clean_text(text: str) -> str:
    """Clean and normalize text fields."""
    if pd.isna(text):
        return ""
    return str(text).strip().title()

def load_movies_to_neo4j(movies_df: pd.DataFrame, connection: GraphDatabase) -> None:
    """Load movie data into Neo4j with progress tracking and error handling."""
    
    logger = logging.getLogger(__name__)
    logger.setLevel(logging.INFO)
    
    # Query templates
    MOVIE_QUERY = """
        MERGE (movie:Movie {title: $title})
        SET movie.year = $year,
            movie.origin = $origin,
            movie.genre = $genre,
            movie.plot = $plot
    """
    
    DIRECTOR_QUERY = """
        MATCH (movie:Movie {title: $title})
        MERGE (director:Director {name: $name})
        MERGE (director)-[:DIRECTED]->(movie)
    """
    
    ACTOR_QUERY = """
        MATCH (movie:Movie {title: $title})
        MERGE (actor:Actor {name: $name})
        MERGE (actor)-[:ACTED_IN]->(movie)
    """

    # Process each movie
    for _, row in tqdm(movies_df.iterrows(), total=len(movies_df), desc="Loading movies"):
        try:
            # Prepare movie parameters
            movie_params = {
                "title": clean_text(row["Title"]),
                #"year": parse_number(row["Release Year"], int),
                "origin": clean_text(row["Origin"]),
                "genre": clean_text(row["Genre"]),
                "plot": str(row["Plot"]).strip()
            }
            
            # Create movie node
            connection.execute_query(MOVIE_QUERY, parameters=movie_params)
            
            # Process directors
            for director in str(row["Director"]).split(" and "):
                director_params = {
                    "name": clean_text(director),
                    "title": movie_params["title"]
                }
                connection.execute_query(DIRECTOR_QUERY, parameters=director_params)
            
            # Process cast
            if pd.notna(row["Cast"]):
                for actor in row["Cast"].split(","):
                    actor_params = {
                        "name": clean_text(actor),
                        "title": movie_params["title"]
                    }
                    connection.execute_query(ACTOR_QUERY, parameters=actor_params)
                    
        except Exception as e:
            logger.error(f"Error loading {row['Title']}: {str(e)}")
            continue

    logger.info("Finished loading movies to Neo4j")

# Load DataFrame to Neo4j
load_movies_to_neo4j(movies, conn)
# Out:
# Loading movies:   0%|          | 0/1000 [00:00<?, ?it/s]ERROR:__main__:Error loading Daniel boone: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Laughing gas: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The adventures of dollie: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The black viper: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A calamitous elopement: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The call of the wild: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The fight for freedom: 'Origin/Ethnicity'
# ERROR:__main__:Error loading At the altar: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A drunkard's reformation: 'Origin/Ethnicity'
# ERROR:__main__:Error loading An arcadian maid: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The house with closed shutters: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A lad from old ireland: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Ramona: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The black arrow: a tale of the two roses: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Brown of harvard: 'Origin/Ethnicity'
# ERROR:__main__:Error loading David copperfield: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Sweet memories: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Dr. jekyll and mr. hyde: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The musketeers of pig alley: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Put yourself in his place: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Barney oldfield's race for a life: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Cohen saves the flag: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The evidence of the film: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The quakeress: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The restless spirit: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The telephone girl and the lady: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The avenging conscience: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The battle of the sexes: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Brewster's millions: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A busy day: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The call of the north: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Captain alvarez: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Caught in a cabaret: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Caught in the rain: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Cinderella: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Cruel, cruel love: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Dough and dynamite: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The escape: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Gentlemen of nerve: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Getting acquainted: 'Origin/Ethnicity'
# ERROR:__main__:Error loading His father's rifle: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Home, sweet home: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The knockout: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Mabel at the wheel: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Mabel's blunder: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Mabel's married life: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Mabel's strange predicament: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Making a living: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The masquerader: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Neptune's daughter: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The new janitor: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The perils of pauline: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The property man: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Rose of the rancho: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The rounders: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Salomy jane: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Should a woman divorce?: 'Origin/Ethnicity'
# Loading movies:   6%|▌         | 57/1000 [00:00<00:01, 569.69it/s]ERROR:__main__:Error loading The squaw man: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Those love pangs: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Tillie's punctured romance: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The wrath of the gods: 'Origin/Ethnicity'
# ERROR:__main__:Error loading After five: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Anna karenina: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Birth of a nation: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The captive: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Carmen: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The champion: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The cheat: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Chimmie fadden out west: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Enoch arden: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A fool there was: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Four feathers: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Fresh from the farm: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Giving them fits: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The italian: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Love, loot and crash: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Pool sharks: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The raven: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The soul of broadway: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The toast of death: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The tramp: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The warrens of virginia: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Work: 'Origin/Ethnicity'
# ERROR:__main__:Error loading 20,000 leagues under the sea: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The abandonment: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The aryan: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The bondman: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Civilization: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A daughter of the gods: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Divorce and the daughter: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Fatty and mabel adrift: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The fireman: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Hoodoo ann: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Hulda from holland: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Joan the woman: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Lights of new york: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Lonesome luke leans to the literary: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Madame x: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Manhattan madness: 'Origin/Ethnicity'
# ERROR:__main__:Error loading One a.m.: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The other side of the door: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Sherlock holmes: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The soul's cycle: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The stepping stone: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Under two flags: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Where are my children?: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Youth's endearing charm: 'Origin/Ethnicity'
# ERROR:__main__:Error loading All aboard: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The bad boy: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Bucking broadway: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The butcher boy: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Camille: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Cheyenne's pal: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Cleopatra: 'Origin/Ethnicity'
# Loading movies:  11%|█▏        | 114/1000 [00:00<00:02, 417.40it/s]ERROR:__main__:Error loading The devil-stone: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Easy street: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Golden rule kate: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Great expectations: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The gulf between: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Her right to live: 'Origin/Ethnicity'
# ERROR:__main__:Error loading His wedding night: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The immigrant: 'Origin/Ethnicity'
# ERROR:__main__:Error loading In again, out again: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The jury of fate: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The little american: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The little princess: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The man without a country: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The mate of the sally ann: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A modern musketeer: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Oh doctor!: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Peggy, the will o' the wisp: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The poor little rich girl: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Reaching for the moon: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Rebecca of sunnybrook farm: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A reckless romeo: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The rough house: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Souls in pawn: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Straight shooting: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A strange transgressor: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The woman god forgot: 'Origin/Ethnicity'
# ERROR:__main__:Error loading All woman: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Amarilly of clothes-line alley: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Are crooks dishonest?: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Arizona: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Beauty and the rogue: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Believe me, xantippe: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The bell boy: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The blue bird: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The bride's awakening: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Cecilia of the pink roses: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The cook: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The craving: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The deciding kiss: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The eyes of julia deep: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The eyes of mystery: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Face value: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The forbidden city: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Friend husband: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Fuss and feathers: 'Origin/Ethnicity'
# Loading movies:  16%|█▌        | 159/1000 [00:00<00:02, 324.40it/s]ERROR:__main__:Error loading The ghost of slumber mountain: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The goddess of lost lake: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The great love: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The greatest thing in life: 'Origin/Ethnicity'
# ERROR:__main__:Error loading He comes up smiling: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Headin' south: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The heart of humanity: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Hearts of the world: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Hell bent: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The house of mirth: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Huck and tom: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The legion of death: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Men who have made love to me: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Mickey: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Mr. fix-it: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Nine-tenths of the law: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The non-stop kid: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Old wives for new: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Out west: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Powers that prey: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Revenge: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The romance of tarzan: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Salomé: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The scarlet drop: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Set free: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Shoulder arms: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Social briars: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Stella maris: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Tarzan of the apes: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Till i come back to you: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Treasure island: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Under the yoke: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The venus model: 'Origin/Ethnicity'
# ERROR:__main__:Error loading We can't have everything: 'Origin/Ethnicity'
# ERROR:__main__:Error loading When do we eat?: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Which woman?: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The whispering chorus: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Anne of green gables: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Ask father: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Back stage: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Better times: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Blind husbands: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Bolshevism on trial: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Broken blossoms: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Bumping into broadway: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Daddy-long-legs: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Dangerous hours: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A day's pleasure: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The delicious little devil: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Don't change your husband: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The echo of youth: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The exquisite thief: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The false faces: 'Origin/Ethnicity'
# ERROR:__main__:Error loading For better, for worse: 'Origin/Ethnicity'
# ERROR:__main__:Error loading From hand to mouth: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The girl who stayed at home: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The grim game: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A gun fightin' gentleman: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Happy though married: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The haunted bedroom: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Hawthorne of the u.s.a.: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Heart o' the hills: 'Origin/Ethnicity'
# Loading movies:  22%|██▏       | 221/1000 [00:00<00:01, 409.89it/s]ERROR:__main__:Error loading His majesty, the american: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The law of men: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Love's prisoner: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Male and female: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A man's fight: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The miracle man: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The miracle of love: 'Origin/Ethnicity'
# ERROR:__main__:Error loading My lady's garter: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Pistols for breakfast: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The probation wife: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Ravished armenia: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The roaring road: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A rogue's romance: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A romance of happy valley: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Sahara: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Scarlet days: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A society exile: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Soldiers of fortune: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Sunnyside: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The test of honor: 'Origin/Ethnicity'
# ERROR:__main__:Error loading True heart susie: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The turn in the road: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The unpainted woman: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The virtuous thief: 'Origin/Ethnicity'
# ERROR:__main__:Error loading What every woman learns: 'Origin/Ethnicity'
# ERROR:__main__:Error loading When the clouds roll by: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The white heather: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The world and its woman: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Yankee doodle in berlin: 'Origin/Ethnicity'
# ERROR:__main__:Error loading You're fired: 'Origin/Ethnicity'
# ERROR:__main__:Error loading 813: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Among those present: 'Origin/Ethnicity'
# ERROR:__main__:Error loading April folly: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Blind youth: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A child for sale: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Convict 13: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The copperhead: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The devil's pass key: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A double-dyed deceiver: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The false road: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The family honor: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The garage: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The girl in number 29: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Hairpins: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Haunted spooks: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Her husband's friend: 'Origin/Ethnicity'
# ERROR:__main__:Error loading High and dizzy: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Huckleberry finn: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The idol dancer: 'Origin/Ethnicity'
# ERROR:__main__:Error loading In the heart of a fool: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The jack-knife man: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Judy of rogue's harbor: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Lady rose's daughter: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The last of the mohicans: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Love: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The love flower: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The man who lost himself: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The mark of zorro: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Neighbors: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Now or never: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Number, please?: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Old lady 31: 'Origin/Ethnicity'
# ERROR:__main__:Error loading One week: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The penalty: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Pollyanna: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Remodeling her husband: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Romance: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The round-up: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The saphead: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The scarecrow: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Sex: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Shore acres: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Silk hosiery: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Silk husbands and calico wives: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The slim princess: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Something to think about: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A splendid hazard: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Suds: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The virgin of stamboul: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Way down east: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Why change your wife?: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Within our gates: 'Origin/Ethnicity'
# Loading movies:  30%|███       | 303/1000 [00:00<00:01, 529.09it/s]ERROR:__main__:Error loading The woman in the suitcase: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The ace of hearts: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The affairs of anatol: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The big punch: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The blot: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The boat: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The conquering power: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Disraeli: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Experience: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Forbidden fruit: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Forever: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The four horsemen of the apocalypse: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The goat: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The haunted house: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Heedless moths: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The high sign: 'Origin/Ethnicity'
# ERROR:__main__:Error loading I do: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Jim the penman: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The kid: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Little lord fauntleroy: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The lotus eater: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The love light: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Love never dies: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The lucky dog: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Mama's affair: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Mother o' mine: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Never weaken: 'Origin/Ethnicity'
# ERROR:__main__:Error loading No woman knows: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The nut: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Orphans of the storm: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The playhouse: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Roads of destiny: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A sailor-made man: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The sea lion: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Seven years bad luck: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The sheik: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Sheltered daughters: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The silver lining: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The sky pilot: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Sure fire: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Tol'able david: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Uncharted seas: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Woman's place: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Beyond the rocks: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A blind bargain: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Blood and sand: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Clarence: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Daydreams: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Dr. jack: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Dusk to dawn: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The electric house: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Fair lady: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Foolish wives: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Grandma's boy: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Heroes of the street: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The loaded door: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Manslaughter: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Moran of the lady letty: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Nanook of the north: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Oliver twist: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The paleface: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Pay day: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Peacock alley: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Peg o' my heart: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The prisoner of zenda: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Ridin' wild: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Robin hood: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Shadows: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Trifling women: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Up and at 'em: 'Origin/Ethnicity'
# ERROR:__main__:Error loading When knighthood was in flower: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Wildness of youth: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The woman he married: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The young rajah: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Ambrose applejohn's adventure: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Ashes of vengeance: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The balloonatic: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Black oxen: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The call of the canyon: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The country kid: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The daring years: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The extra girl: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Gentle julia: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The hunchback of notre dame: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Merry-go-round: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Our hospitality: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The pilgrim: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Safety last!: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Scaramouche: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The shock: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The shriek of araby: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The silent command: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Slippy mcgee: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Souls for sale: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The ten commandments: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Three ages: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The white sister: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Why worry?: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A woman of paris: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The age of innocence: 'Origin/Ethnicity'
# ERROR:__main__:Error loading America: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The arab: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Beau brummel: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Circe, the enchantress: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Dante's inferno: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The enchanted cottage: 'Origin/Ethnicity'
# Loading movies:  41%|████      | 409/1000 [00:00<00:00, 685.29it/s]ERROR:__main__:Error loading The family secret: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Feet of clay: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Girl shy: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Greed: 'Origin/Ethnicity'
# ERROR:__main__:Error loading He who gets slapped: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Helen's babies: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Her night of romance: 'Origin/Ethnicity'
# ERROR:__main__:Error loading His hour: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Hot water: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The iron horse: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Isn't life wonderful: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Janice meredith: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Listen lester: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Manhandled: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Monsieur beaucaire: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The navigator: 'Origin/Ethnicity'
# ERROR:__main__:Error loading One night in rome: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Peter pan: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The red lily: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Romola: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The sea hawk: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Secrets: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Sherlock, jr.: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The shooting of dan mcgrew: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The thief of bagdad: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Three weeks: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Wild oranges: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Wine of youth: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The yankee consul: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Adventure: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Ben-hur: a tale of the christ: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The big parade: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Cheaper to marry: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The circle: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Cobra: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Confessions of a queen: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Dangerous innocence: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The dark angel: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Don q, son of zorro: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The eagle: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Fifty-fifty: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The freshman: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Go west: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The gold rush: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Hogan's alley: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Kentucky pride: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The king on main street: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A kiss for cinderella: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The lady: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Lady windermere's fan: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Little annie rooney: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The lost world: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The lucky devil: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The lucky horseshoe: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The mad whirl: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The man who found himself: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The mystic: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Old clothes: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Phantom of the opera: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The plastic age: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Pretty ladies: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Proud flesh: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The rag man: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Sally, irene and mary: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Sally of the sawdust: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The salvation hunters: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Seven chances: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Seven sinners: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Smouldering fires: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Stage struck: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The teaser: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Time, the comedian: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Too many kisses: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The tower of lies: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The trail rider: 'Origin/Ethnicity'
# Loading movies:  48%|████▊     | 484/1000 [00:00<00:00, 568.14it/s]ERROR:__main__:Error loading Tumbleweeds: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The unholy three: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Wizard of oz: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Wolf blood: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Across the pacific: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Bardelys the magnificent: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The bat: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Battling butler: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Beau geste: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The bells: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The better 'ole: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Beverly of graustark: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The black pirate: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The blackbird: 'Origin/Ethnicity'
# ERROR:__main__:Error loading La bohème: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The boy friend: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Broken hearts of hollywood: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Cruise of the jasper b: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Dance madness: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Don juan: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Ella cinders: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The exquisite sinner: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Fine manners: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Flesh and the devil: 'Origin/Ethnicity'
# ERROR:__main__:Error loading For heaven's sake: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The gay deceiver: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The general: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The great gatsby: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The great k & a train robbery: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Hands up!: 'Origin/Ethnicity'
# ERROR:__main__:Error loading High steppers: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The joy girl: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Kid boots: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Kiki: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Looking for trouble: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The magician: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Mantrap: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Mare nostrum: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Miss brewster's millions: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The new klondike: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Old ironsides: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Private izzy murphy: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The sea beast: 'Origin/Ethnicity'
# ERROR:__main__:Error loading So this is paris: 'Origin/Ethnicity'
# ERROR:__main__:Error loading So's your old man: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The sorrows of satan: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The strong man: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The temptress: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Torrent: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Tramp, tramp, tramp: 'Origin/Ethnicity'
# ERROR:__main__:Error loading What price glory?: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The winning of barbara worth: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Adam and evil: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The cat and the canary: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Chang: a drama of the wilderness: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Chicago: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Children of divorce: 'Origin/Ethnicity'
# ERROR:__main__:Error loading College: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The college hero: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The enemy: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The fair co-ed: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The first auto: 'Origin/Ethnicity'
# ERROR:__main__:Error loading For the love of mike: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Foreign devils: 'Origin/Ethnicity'
# Loading movies:  55%|█████▍    | 548/1000 [00:01<00:00, 554.38it/s]ERROR:__main__:Error loading The garden of allah: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The girl from chicago: 'Origin/Ethnicity'
# ERROR:__main__:Error loading His first flame: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Hula: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Husband hunters: 'Origin/Ethnicity'
# ERROR:__main__:Error loading It: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The jazz singer: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The kid brother: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The king of kings: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Knockout reilly: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A little journey: 'Origin/Ethnicity'
# ERROR:__main__:Error loading London after midnight: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Long pants: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The love of sunya: 'Origin/Ethnicity'
# ERROR:__main__:Error loading My best girl: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The red mill: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Resurrection: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The road to romance: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Rookies: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The scar of shame: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The show: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Spring fever: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The student prince in old heidelberg: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Sunrise: a song of two humans: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Two arabian knights: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Underworld: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The unknown: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The way of all flesh: 'Origin/Ethnicity'
# ERROR:__main__:Error loading When a man loves: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Why girls love sailors: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Wings: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The yankee clipper: 'Origin/Ethnicity'
# ERROR:__main__:Error loading 4 devils: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Abie's irish rose: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Across to singapore: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The air circus: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Alias jimmy valentine: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The barker: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Beware of bachelors: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The cameraman: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The cardboard lover: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The cavalier: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The circus: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The crimson city: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The crowd: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The divine woman: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The docks of new york: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Don't marry: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Doomsday: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Dream of love: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Dressed to kill: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Drums of love: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Dry martini: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Feel my pulse: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Forbidden hours: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Four sons: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Four walls: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Gang war: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The garden of eden: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The gateway of the moon: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A girl in every port: 'Origin/Ethnicity'
# Loading movies:  61%|██████    | 609/1000 [00:01<00:00, 446.46it/s]ERROR:__main__:Error loading Glorious betsy: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The godless girl: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Half a bride: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Hangman's house: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The hawk's nest: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Heart trouble: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A lady of chance: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The last command: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Laugh, clown, laugh: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The law of the range: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The legion of the condemned: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Lilac time: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The lion and the mouse: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Love me and the world is mine: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The magnificent flirt: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The man who laughs: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The matinee idol: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The mating call: 'Origin/Ethnicity'
# ERROR:__main__:Error loading My man: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The mysterious lady: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Naughty baby: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Night watch: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Noah's ark: 'Origin/Ethnicity'
# ERROR:__main__:Error loading On trial: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Our dancing daughters: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The patriot: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The red dance: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Red hair: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Sadie thompson: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Say it with sables: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Sharp shooters: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Show girl: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Show people: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The showdown: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The singing fool: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The smart set: 'Origin/Ethnicity'
# ERROR:__main__:Error loading So this is love?: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Speedy: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Steamboat bill, jr.: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Stop that man!: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Street angel: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Submarine: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Tenderloin: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The terror: 'Origin/Ethnicity'
# ERROR:__main__:Error loading That certain thing: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Three weekends: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The viking: 'Origin/Ethnicity'
# ERROR:__main__:Error loading We faw down: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The wedding march: 'Origin/Ethnicity'
# ERROR:__main__:Error loading West of zanzibar: 'Origin/Ethnicity'
# ERROR:__main__:Error loading West point: 'Origin/Ethnicity'
# Loading movies:  66%|██████▌   | 660/1000 [00:01<00:01, 332.39it/s]ERROR:__main__:Error loading What a night!: 'Origin/Ethnicity'
# ERROR:__main__:Error loading While the city sleeps: 'Origin/Ethnicity'
# ERROR:__main__:Error loading White shadows in the south seas: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Wife savers: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The wind: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A woman of affairs: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Acquitted: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Alibi: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Applause: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The argyle case: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The aviator: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Berth marks: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Betrayal: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Big business: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Broadway: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Broadway babies: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The broadway melody: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Bulldog drummond: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The canary murder case: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Captain lash: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Careers: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The case of lena smith: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Children of the ritz: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Close harmony: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The cocoanuts: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Coquette: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The cock-eyed world: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Dance hall: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The dance of life: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Dangerous curves: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A dangerous woman: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The delightful rogue: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Desert nights: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The desert song: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The divine lady: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The donovan affair: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Drag: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Dynamite: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Eternal love: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Fancy baggage: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Fast company: 'Origin/Ethnicity'
# Loading movies:  70%|███████   | 701/1000 [00:01<00:00, 338.22it/s]ERROR:__main__:Error loading Flight: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The flying fleet: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Footlights and fools: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The forward pass: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Fox movietone follies of 1929: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The gamblers: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Glorifying the american girl: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Gold diggers of broadway: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The great divide: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The great gabbo: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Half marriage: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Hallelujah!: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Happy days: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Hardboiled rose: 'Origin/Ethnicity'
# ERROR:__main__:Error loading His glorious night: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Honky tonk: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Jazz heaven: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The kiss: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The lady lies: 'Origin/Ethnicity'
# ...
# ERROR:__main__:Error loading The squall: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Stark mad: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Street girl: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Sunny side up: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Syncopation: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Synthetic sin: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Tanned legs: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The thirteenth chair: 'Origin/Ethnicity'
# ERROR:__main__:Error loading This is heaven: 'Origin/Ethnicity'
# ERROR:__main__:Error loading This thing called love: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Thunderbolt: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Trent's last case: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The trespasser: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Under the southern cross: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The vagabond lover: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The valiant: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The very idea: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The virginian: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Weary river: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Wedding rings: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Welcome danger: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Where east is east: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Why be good?: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Wild orchids: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The wolf song: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Woman trap: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Words and music: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The younger generation: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Abraham lincoln: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Africa speaks!: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Alias french gertie: 'Origin/Ethnicity'
# ERROR:__main__:Error loading All quiet on the western front: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Animal crackers: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Anna christie: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The bat whispers: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Beau bandit: 'Origin/Ethnicity'
# Loading movies:  80%|███████▉  | 796/1000 [00:01<00:00, 326.74it/s]ERROR:__main__:Error loading Behind the make-up: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The benson murder case: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The big house: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The big pond: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The big trail: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The bishop murder case: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Born reckless: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Borrowed wives: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The boudoir diplomat: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Bride of the regiment: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Bright lights: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Call of the flesh: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The case of sergeant grischa: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Chasing rainbows: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Check and double check: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Children of pleasure: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Conspiracy: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Courage: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The cuckoos: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Dancing sweeties: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Dangerous nan mcgrew: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The dawn patrol: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The devil to pay!: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The devil's holiday: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The divorcee: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Dixiana: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The doorway to hell: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Doughboys: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Dumbbells in ermine: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Extravagance: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The fall guy: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Fast and loose: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Feet first: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The florodora girl: 'Origin/Ethnicity'
# ERROR:__main__:Error loading For the defense: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Framed: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Free and easy: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The furies: 'Origin/Ethnicity'
# Loading movies:  83%|████████▎ | 834/1000 [00:02<00:00, 211.46it/s]ERROR:__main__:Error loading General crack: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Girl of the port: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The girl said no: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The gorilla: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The green goddess: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Golden dawn: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Going wild: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Grumpy: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Half shot at sunrise: 'Origin/Ethnicity'
# ERROR:__main__:Error loading He knew women: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Hell harbor: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Hell's angels: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Hell's heroes: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Hide-out: 'Origin/Ethnicity'
# ERROR:__main__:Error loading High society blues: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Hit the deck: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Hold everything: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Hook, line and sinker: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Hot curves: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Inside the lines: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Isle of escape: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Journey's end: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Just imagine: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Kismet: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Ladies of leisure: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A lady surrenders: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A lady to love: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The lash: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Laughter: 'Origin/Ethnicity'
# Loading movies:  86%|████████▋ | 863/1000 [00:02<00:00, 216.18it/s]ERROR:__main__:Error loading Lawful larceny: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Leathernecking: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Let us be gay: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The life of the party: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Loose ankles: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Love comes along: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Lovin' the ladies: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Madam satan: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Mamba: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Mammy: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The man from blankley's: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A man from wyoming: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The man hunter: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The matrimonial bed: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Maybe it's love: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Midnight mystery: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Min and bill: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Moby dick: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Montana moon: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Monte carlo: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Morocco: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Mothers cry: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Murder will out: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Near the rainbow's end: 'Origin/Ethnicity'
# ERROR:__main__:Error loading No, no, nanette: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A notorious affair: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Numbered men: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The office wife: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Oh sailor behave: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Oklahoma cyclone: 'Origin/Ethnicity'
# ERROR:__main__:Error loading On your back: 'Origin/Ethnicity'
# ERROR:__main__:Error loading One night at susie's: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Only the brave: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The other tomorrow: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Our blushing brides: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Outside the law: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Outward bound: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Part time wife: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The pay-off: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Playing around: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Raffles: 'Origin/Ethnicity'
# Loading movies:  90%|█████████ | 904/1000 [00:02<00:00, 250.57it/s]ERROR:__main__:Error loading Recaptured love: 'Origin/Ethnicity'
# ERROR:__main__:Error loading River's end: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Road to paradise: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The rogue song: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Rough romance: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Rough waters: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The runaway bride: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Safety in numbers: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The sap from syracuse: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Sarah and son: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Scarlet pages: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The sea god: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Second choice: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The second floor mystery: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Second wife: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Shadow of the law: 'Origin/Ethnicity'
# ERROR:__main__:Error loading She's my weakness: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Shooting straight: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Show girl in hollywood: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The silver horde: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Sin takes a holiday: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Sinners' holiday: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The social lion: 'Origin/Ethnicity'
# ERROR:__main__:Error loading A soldier's plaything: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Son of the gods: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Song of the flame: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Song of the west: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Soup to nuts: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The spoilers: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Spring is here: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Street of chance: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Such men are dangerous: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Sunny: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Sweet kitty bellairs: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Sweet mama: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The texan: 'Origin/Ethnicity'
# ERROR:__main__:Error loading They learned about women: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Those three french girls: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Those who dance: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Three faces east: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Tom sawyer: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Troopers three: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Up the river: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The vagabond king: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Viennese nights: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The virtuous sin: 'Origin/Ethnicity'
# ERROR:__main__:Error loading War nurse: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The way of all men: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Way out west: 'Origin/Ethnicity'
# ERROR:__main__:Error loading What a man!: 'Origin/Ethnicity'
# Loading movies:  95%|█████████▌| 954/1000 [00:02<00:00, 301.78it/s]ERROR:__main__:Error loading What men want: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Wide open: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The widow from chicago: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Young eagles: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Young man of manhattan: 'Origin/Ethnicity'
# ERROR:__main__:Error loading 24 hours: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Alexander hamilton: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Ambassador bill: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Annabelle's affairs: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Are these our children?: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Arrowsmith: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The avenger: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Bachelor apartment: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The bachelor father: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Bad company: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Bad girl: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Bad sister: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Beau ideal: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Behind office doors: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Beyond victory: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The big shot: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The black camel: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Blonde crazy: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Body and soul: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Border law: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Born to love: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Bought: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Branded: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Broadminded: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Captain applejack: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Caught cheating: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Caught plastered: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The champ: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Chances: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Charlie chan carries on: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Children of dreams: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Cimarron: 'Origin/Ethnicity'
# Loading movies:  99%|█████████▉| 991/1000 [00:02<00:00, 294.31it/s]ERROR:__main__:Error loading City lights: 'Origin/Ethnicity'
# ERROR:__main__:Error loading City streets: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The common law: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Confessions of a co-ed: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Consolation marriage: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Corsair: 'Origin/Ethnicity'
# ERROR:__main__:Error loading Cracked nuts: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The criminal code: 'Origin/Ethnicity'
# ERROR:__main__:Error loading The cuban love song: 'Origin/Ethnicity'
# Loading movies: 100%|██████████| 1000/1000 [00:02<00:00, 359.59it/s]
# INFO:__main__:Finished loading movies to Neo4j

# %%
query = """
MATCH (m:Movie)-[:ACTED_IN]-(a:Actor)
RETURN m.title, a.name
LIMIT 10;
"""
conn.execute_query(query)
results = conn.execute_query(query)
# for record in results:
#     print(record)
# Out:
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownPropertyKeyWarning} {category: UNRECOGNIZED} {title: The provided property key is not in the database} {description: One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: name)} {position: line: 3, column: 19, offset: 57} for query: '\nMATCH (m:Movie)-[:ACTED_IN]-(a:Actor)\nRETURN m.title, a.name\nLIMIT 10;\n'
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownPropertyKeyWarning} {category: UNRECOGNIZED} {title: The provided property key is not in the database} {description: One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: title)} {position: line: 3, column: 10, offset: 48} for query: '\nMATCH (m:Movie)-[:ACTED_IN]-(a:Actor)\nRETURN m.title, a.name\nLIMIT 10;\n'
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownLabelWarning} {category: UNRECOGNIZED} {title: The provided label is not in the database.} {description: One of the labels in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing label name is: Movie)} {position: line: 2, column: 10, offset: 10} for query: '\nMATCH (m:Movie)-[:ACTED_IN]-(a:Actor)\nRETURN m.title, a.name\nLIMIT 10;\n'
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownRelationshipTypeWarning} {category: UNRECOGNIZED} {title: The provided relationship type is not in the database.} {description: One of the relationship types in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing relationship type is: ACTED_IN)} {position: line: 2, column: 19, offset: 19} for query: '\nMATCH (m:Movie)-[:ACTED_IN]-(a:Actor)\nRETURN m.title, a.name\nLIMIT 10;\n'
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownLabelWarning} {category: UNRECOGNIZED} {title: The provided label is not in the database.} {description: One of the labels in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing label name is: Actor)} {position: line: 2, column: 32, offset: 32} for query: '\nMATCH (m:Movie)-[:ACTED_IN]-(a:Actor)\nRETURN m.title, a.name\nLIMIT 10;\n'
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownPropertyKeyWarning} {category: UNRECOGNIZED} {title: The provided property key is not in the database} {description: One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: name)} {position: line: 3, column: 19, offset: 57} for query: '\nMATCH (m:Movie)-[:ACTED_IN]-(a:Actor)\nRETURN m.title, a.name\nLIMIT 10;\n'
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownPropertyKeyWarning} {category: UNRECOGNIZED} {title: The provided property key is not in the database} {description: One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: title)} {position: line: 3, column: 10, offset: 48} for query: '\nMATCH (m:Movie)-[:ACTED_IN]-(a:Actor)\nRETURN m.title, a.name\nLIMIT 10;\n'
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownLabelWarning} {category: UNRECOGNIZED} {title: The provided label is not in the database.} {description: One of the labels in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing label name is: Movie)} {position: line: 2, column: 10, offset: 10} for query: '\nMATCH (m:Movie)-[:ACTED_IN]-(a:Actor)\nRETURN m.title, a.name\nLIMIT 10;\n'
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownRelationshipTypeWarning} {category: UNRECOGNIZED} {title: The provided relationship type is not in the database.} {description: One of the relationship types in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing relationship type is: ACTED_IN)} {position: line: 2, column: 19, offset: 19} for query: '\nMATCH (m:Movie)-[:ACTED_IN]-(a:Actor)\nRETURN m.title, a.name\nLIMIT 10;\n'
# WARNING:neo4j.notifications:Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownLabelWarning} {category: UNRECOGNIZED} {title: The provided label is not in the database.} {description: One of the labels in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing label name is: Actor)} {position: line: 2, column: 32, offset: 32} for query: '\nMATCH (m:Movie)-[:ACTED_IN]-(a:Actor)\nRETURN m.title, a.name\nLIMIT 10;\n'

# %%
conn.reset_database()
# Out:
# Database resetted successfully!

# %% [markdown]
# LLM Upload

# %%
# Initialize the LLM
llm = GoogleGenerativeAI(model="gemini-1.5-flash-latest", google_api_key= "AIzaSyB_Ykzslx0N_kKYeUN5jPr-LF7gLqo8ddM") 



df = movies.copy()

# Step 1: Define Node Labels and Properties
node_structure = "\n".join(
    [f"{col}: {', '.join(map(str, df[col].unique()[:3]))}..." for col in df.columns]
)

print(node_structure)
# Out:
# Title: Daniel boone, Laughing gas, The adventures of dollie...
# Ethnicity: American...
# Director: Wallace mccutcheon and ediwin s. porter, Edwin stanton porter, D. w. griffith...
# Cast: William craven, florence lawrence, Bertha regustus, edward boulden, Arthur v. johnson, linda arvidson...
# Genre: Biographical, Comedy, Drama...
# Plot: Boone's daughter befriends an indian maiden as boone and his companion start out on a hunting expedition. while he is away, boone's cabin is attacked by the indians, who set it on fire and abduct boone's daughter. boone returns, swears vengeance, then heads out on the trail to the indian camp. his daughter escapes but is chased. the indians encounter boone, which sets off a huge fight on the edge of a cliff. a burning arrow gets shot into the indian camp. boone gets tied to the stake and tortured. the burning arrow sets the indian camp on fire, causing panic. boone is rescued by his horse, and boone has a knife fight in which he kills the indian chief.[2], The plot is that of a black woman going to the dentist for a toothache and being given laughing gas. on her way walking home, and in other situations, she can't stop laughing, and everyone she meets "catches" the laughter from her, including a vendor and police officers., On a beautiful summer day a father and mother take their daughter dollie on an outing to the river. the mother refuses to buy a gypsy's wares. the gypsy tries to rob the mother, but the father drives him off. the gypsy returns to the camp and devises a plan. they return and kidnap dollie while her parents are distracted. a rescue crew is organized, but the gypsy takes dollie to his camp. they gag dollie and hide her in a barrel before the rescue party gets to the camp. once they leave the gypsies and escapes in their wagon. as the wagon crosses the river, the barrel falls into the water. still sealed in the barrel, dollie is swept downstream in dangerous currents. a boy who is fishing in the river finds the barrel, and dollie is reunited safely with her parents....

# %%
# Setup logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

def validate_node_definition(node_def: Dict) -> bool:
    """Validate node definition structure"""
    if not isinstance(node_def, dict):
        return False
    return all(
        isinstance(v, dict) and all(isinstance(k, str) for k in v.keys())
        for v in node_def.values()
    )

@retry(stop=stop_after_attempt(3), wait=wait_exponential(multiplier=1, min=4, max=10))
def get_node_definitions(chain, structure: str, example: Dict) -> Dict[str, Dict[str, str]]:
    """Get node definitions with retry logic"""
    try:
        # Get response from LLM
        response = chain.invoke({"structure": structure, "example": example})
     
        
        # Parse response
        node_defs = ast.literal_eval(response)
        
        # Validate structure
        if not validate_node_definition(node_defs):
            raise ValueError("Invalid node definition structure")
            
        return node_defs
        
    except (ValueError, SyntaxError) as e:
        logger.error(f"Error parsing node definitions: {e}")
        raise

# Updated node definition template
node_example = {
    "NodeLabel1": {"property1": "row['property1']", "property2": "row['property2'], ..."},
    "NodeLabel2": {"property1": "row['property1']", "property2": "row['property2'], ..."},
    "NodeLabel3": {"property1": "row['property1']", "property2": "row['property2'], ..."},
}

#removed "If a property can be its own node, include it as a separate node label" -- causing duplicates
define_nodes_prompt = PromptTemplate(
    input_variables=["example", "structure"],
    template=("""
        Analyze the dataset structure below and extract the entity labels for nodes and their properties.\n
        The node properties should be based on the dataset columns and their values.\n
        Return the result as a dictionary where the keys are the node labels and the values are the node properties.\n\n
        Example: {example}\n\n
        
        Dataset Structure:\n{structure}\n\n
              
        Make sure to include all the possible node labels and their properties.\n
        Please do not report triple backticks to identify a code block, just return the list of tuples.\n
        Return only the dictionary containing node labels and properties, and don't include any other text or quotation.
        
        """
    ),
)

# Execute with error handling
try:
    node_chain = define_nodes_prompt | llm

    node_definitions = get_node_definitions(node_chain, structure=node_structure, example=node_example)
    logger.info(f"Node Definitions: {node_definitions}")
except Exception as e:
    logger.error(f"Failed to get node definitions: {e}")
    raise
# Out:
# INFO:__main__:Node Definitions: {'Movie': {'Title': "row['Title']", 'Ethnicity': "row['Ethnicity']", 'Director': "row['Director']", 'Cast': "row['Cast']", 'Genre': "row['Genre']", 'Plot': "row['Plot']"}}

# %%
class RelationshipIdentifier:
    """Identifies relationships between nodes in a graph database."""
    
    RELATIONSHIP_EXAMPLE = [
        ("NodeLabel1", "RelationshipLabel", "NodeLabel2"),
        ("NodeLabel1", "RelationshipLabel", "NodeLabel3"),
        ("NodeLabel2", "RelationshipLabel", "NodeLabel3"),
    ]


    PROMPT_TEMPLATE = PromptTemplate(
    input_variables=["structure", "node_definitions", "example"],
    template="""
        Consider the following Dataset Structure:\n{structure}\n\n

        Consider the following Node Definitions:\n{node_definitions}\n\n

        Based on the dataset structure and node definitions, identify relationships (edges) between nodes.\n
        Return the relationships as a list of triples where each triple contains the start node label, relationship label, and end node label, and each triple is a tuple.\n
        Please return only the list of tuples. Please do not report triple backticks to identify a code block, just return the list of tuples.\n\n

        Example:\n{example}
        """
)

    def __init__(self, llm: Any, logger: logging.Logger = None):
        self.llm = llm
        self.logger = logger or logging.getLogger(__name__)
        self.chain = self.PROMPT_TEMPLATE | self.llm

    def validate_relationships(self, relationships: List[Tuple]) -> bool:
        """Validate relationship structure."""
        return all(
            isinstance(rel, tuple) and 
            len(rel) == 3 and 
            all(isinstance(x, str) for x in rel)
            for rel in relationships
        )

    @retry(stop=stop_after_attempt(3), wait=wait_exponential(multiplier=1, min=4, max=10))
    def identify_relationships(self, structure: str, node_definitions: Dict) -> List[Tuple]:
        """Identify relationships with retry logic."""
        try:
            # response = self.chain.run(
            #     structure=structure,
            #     node_definitions=str(node_definitions),
            #     example=str(self.RELATIONSHIP_EXAMPLE)
            # )
            response = self.chain.invoke({
                "structure": structure, 
                "node_definitions": str(node_definitions), 
                "example": str(self.RELATIONSHIP_EXAMPLE)
            })
            
            relationships = ast.literal_eval(response)
            
            
            if not self.validate_relationships(relationships):
                raise ValueError("Invalid relationship structure")
                
            self.logger.info(f"Identified {len(relationships)} relationships")
            return relationships
            
        except Exception as e:
            self.logger.error(f"Error identifying relationships: {e}")
            raise

    def get_relationship_types(self) -> List[str]:
        """Extract unique relationship types."""
        return list(set(rel[1] for rel in self.identify_relationships()))

# Usage
identifier = RelationshipIdentifier(llm=llm)
relationships = identifier.identify_relationships(node_structure, node_definitions)
print("Relationships:", relationships)
# Out:
# INFO:__main__:Identified 5 relationships
# Relationships: [('Movie', 'HAS_ETHNICITY', 'Ethnicity'), ('Movie', 'HAS_DIRECTOR', 'Director'), ('Movie', 'HAS_CAST', 'Cast'), ('Movie', 'HAS_GENRE', 'Genre'), ('Movie', 'HAS_PLOT', 'Plot')]

# %%
class CypherQueryBuilder:
    """Builds Cypher queries for Neo4j graph database."""

    INPUT_EXAMPLE = """
    NodeLabel1: value1, value2
    NodeLabel2: value1, value2
    """
    
    EXAMPLE_CYPHER = example_cypher = """
    CREATE (n1:NodeLabel1 {property1: "row['property1']", property2: "row['property2']"})
    CREATE (n2:NodeLabel2 {property1: "row['property1']", property2: "row['property2']"})
    CREATE (n1)-[:RelationshipLabel]->(n2);
    """
    #added special character check to be wrapped into `` - property error
    PROMPT_TEMPLATE = PromptTemplate(
    input_variables=["structure", "node_definitions", "relationships", "example"],
    template="""
        Consider the following Node Definitions:\n{node_definitions}\n\n
        Consider the following Relationships:\n{relationships}\n\n
        Generate Cypher queries to create nodes and relationships using the node definitions and relationships below. Remember to replace the placeholder values with actual data from the dataset. \n
        Ensure that all Cypher queries include appropriate opening and closing brackets \n
        Return separate Cypher `CREATE` statements for each node and relationship.
        Include all the properties in the Node Definitions for each node as defined and create relationships.\n 
        Ensure special character is wrapped into ``. \n
        Return a single string with each query separated by a semicolon.\n
        Don't include any other text or quotation marks in the response.\n
        Please return only the string containing Cypher queries. Please do not report triple backticks to identify a code block.\n\n

        Example Input:\n{input}\n\n

        Example Output Cypher query:\n{cypher}
    """
)

    def __init__(self, llm: Any, logger: logging.Logger = None):
        self.llm = llm
        self.logger = logger or logging.getLogger(__name__)
        # self.chain = LLMChain(llm=llm, prompt=self.PROMPT_TEMPLATE)
        self.chain = self.PROMPT_TEMPLATE | self.llm

    def validate_cypher_query(self, query: str) -> bool:
        """Validate Cypher query syntax using LLM and regex patterns."""
        
        VALIDATION_PROMPT = PromptTemplate(
            input_variables=["query"],
            template="""
            Validate this Cypher query and return TRUE or FALSE:
            
            Query: {query}
            
            Rules to check:
            1. Valid CREATE statements
            2. Proper property formatting
            3. Valid relationship syntax
            4. No missing parentheses
            5. Valid property names
            6. Valid relationship types
            
            Return only TRUE if query is valid, FALSE if invalid.
            """
        )
        
        try:
            # Basic pattern validation
            basic_valid = all(re.search(pattern, query) for pattern in [
                r'CREATE \(',  
                r'\{.*?\}',    
                r'\)-\[:.*?\]->'
            ])
            
            if not basic_valid:
                return False
                
            # LLM validation
            validation_chain = VALIDATION_PROMPT | self.llm
            result = validation_chain.invoke({"query": query})
            
            # Parse result
            is_valid = "TRUE" in result.upper()
            
            if not is_valid:
                self.logger.warning(f"LLM validation failed for query: {query}")
                
            return is_valid
            
        except Exception as e:
            self.logger.error(f"Validation error: {e}")
            return False


    def sanitize_query(self, query: str) -> str:
        """Sanitize and format Cypher query."""
        
        return (query
                .strip()
                .replace('\n', ' ')
                .replace('  ', ' ')
                .replace("'row[", "row['")
                .replace("]'", "']"))

    

       
    @retry(stop=stop_after_attempt(3), wait=wait_exponential(multiplier=1, min=4, max=10))
    def build_queries(self, node_definitions: Dict, relationships: List) -> str:
        """Build Cypher queries with retry logic."""
        try:
            response = self.chain.invoke({
                "node_definitions": str(node_definitions),
                "relationships": str(relationships),
                "input": self.INPUT_EXAMPLE,
                "cypher": self.EXAMPLE_CYPHER
            })


            #Get response inside triple backticks
            if '```' in response:
                response = response.split('```')[0]

            # Sanitize response
            queries = self.sanitize_query(response)
            
            
            # Validate queries
            if not self.validate_cypher_query(queries):
                raise ValueError("Invalid Cypher query syntax")
                
            self.logger.info("Successfully generated Cypher queries")
            return queries
            
        except Exception as e:
            self.logger.error(f"Error building Cypher queries: {e}")
            raise

    def split_queries(self, queries: str) -> List[str]:
        """Split combined queries into individual statements."""
        return [q.strip() for q in queries.split(';') if q.strip()]

# Usage
builder = CypherQueryBuilder(llm=llm)
cypher_queries = builder.build_queries(node_definitions, relationships)
print("Cypher Queries:", cypher_queries)
# Out:
# WARNING:__main__:LLM validation failed for query: CREATE (m:Movie {Title: "row['Title']", Ethnicity: "row['Ethnicity']", Director: "row['Director']", Cast: "row['Cast']", Genre: "row['Genre']", Plot: "row['Plot']"})CREATE (e:Ethnicity {name: "row['Ethnicity']"})CREATE (d:Director {name: "row['Director']"})CREATE (c:Cast {name: "row['Cast']"})CREATE (g:Genre {name: "row['Genre']"})CREATE (p:Plot {description: "row['Plot']"})CREATE (m)-[:HAS_ETHNICITY]->(e)CREATE (m)-[:HAS_DIRECTOR]->(d)CREATE (m)-[:HAS_CAST]->(c)CREATE (m)-[:HAS_GENRE]->(g)CREATE (m)-[:HAS_PLOT]->(p)
# ERROR:__main__:Error building Cypher queries: Invalid Cypher query syntax
# WARNING:__main__:LLM validation failed for query: CREATE (m:Movie {Title: "row['Title']", Ethnicity: "row['Ethnicity']", Director: "row['Director']", Cast: "row['Cast']", Genre: "row['Genre']", Plot: "row['Plot']"})CREATE (e:Ethnicity {name: "row['Ethnicity']"})CREATE (d:Director {name: "row['Director']"})CREATE (c:Cast {name: "row['Cast']"})CREATE (g:Genre {name: "row['Genre']"})CREATE (p:Plot {description: "row['Plot']"})CREATE (m)-[:HAS_ETHNICITY]->(e)CREATE (m)-[:HAS_DIRECTOR]->(d)CREATE (m)-[:HAS_CAST]->(c)CREATE (m)-[:HAS_GENRE]->(g)CREATE (m)-[:HAS_PLOT]->(p);
# ERROR:__main__:Error building Cypher queries: Invalid Cypher query syntax
# WARNING:__main__:LLM validation failed for query: CREATE (m:Movie {Title: "row['Title']", Ethnicity: "row['Ethnicity']", Director: "row['Director']", Cast: "row['Cast']", Genre: "row['Genre']", Plot: "row['Plot']"})CREATE (e:Ethnicity {name: "row['Ethnicity']"})CREATE (d:Director {name: "row['Director']"})CREATE (c:Cast {name: "row['Cast']"})CREATE (g:Genre {name: "row['Genre']"})CREATE (p:Plot {description: "row['Plot']"})CREATE (m)-[:HAS_ETHNICITY]->(e)CREATE (m)-[:HAS_DIRECTOR]->(d)CREATE (m)-[:HAS_CAST]->(c)CREATE (m)-[:HAS_GENRE]->(g)CREATE (m)-[:HAS_PLOT]->(p);
# ERROR:__main__:Error building Cypher queries: Invalid Cypher query syntax
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Desktop/FediRAG/myenv/lib/python3.13/site-packages/tenacity/__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     477 try:
# --> 478     result = fn(*args, **kwargs)
#     479 except BaseException:  # noqa: B902
#
# Cell In[26], line 126, in CypherQueryBuilder.build_queries(self, node_definitions, relationships)
#     125 if not self.validate_cypher_query(queries):
# --> 126     raise ValueError("Invalid Cypher query syntax")
#     128 self.logger.info("Successfully generated Cypher queries")
#
# ValueError: Invalid Cypher query syntax
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# Cell In[26], line 141
#     139 # Usage
#     140 builder = CypherQueryBuilder(llm=llm)
# --> 141 cypher_queries = builder.build_queries(node_definitions, relationships)
#     142 print("Cypher Queries:", cypher_queries)
#
# File ~/Desktop/FediRAG/myenv/lib/python3.13/site-packages/tenacity/__init__.py:336, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     334 copy = self.copy()
#     335 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336 return copy(f, *args, **kw)
#
# File ~/Desktop/FediRAG/myenv/lib/python3.13/site-packages/tenacity/__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File ~/Desktop/FediRAG/myenv/lib/python3.13/site-packages/tenacity/__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File ~/Desktop/FediRAG/myenv/lib/python3.13/site-packages/tenacity/__init__.py:419, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     417 if self.reraise:
#     418     raise retry_exc.reraise()
# --> 419 raise retry_exc from fut.exception()
#
# RetryError: RetryError[<Future at 0x124fd0d50 state=finished raised ValueError>]

# %% [markdown]
# Loading data to Graph DB

# %%
# Iterate over dataframe with progress bar
logs = ""
total_rows = len(df)

def sanitize_value(value):
    if isinstance(value, str):
        return value.replace('"', '')
    return str(value)

for index, row in tqdm(df.iterrows(), 
                      total=total_rows,
                      desc="Loading data to Neo4j",
                      position=0,
                      leave=True):
    
    # Replace placeholders with actual values
    cypher_query = cypher_queries
    for column in df.columns:
        cypher_query = cypher_query.replace(
            f"row['{column}']", 
            f'{sanitize_value(row[column])}'
        )
       # print(sanitize_value(row[column]))
    
    try:
        # Execute query and update progress
        conn.execute_query(cypher_query)
    except Exception as e:
        logs += f"Error on row {index+1}: {str(e)}\n"

# Display logs
print(logs) # Uncomment to display logs
